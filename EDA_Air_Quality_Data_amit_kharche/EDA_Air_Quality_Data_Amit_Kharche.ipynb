# %% [markdown]
# # **EDA_Air_Quality_Analysis**
# # **By Amit Kharche**
# **Follow me** on [Linkedin](https://www.linkedin.com/in/amit-kharche) and [Medium](https://medium.com/@amitkharche14) for more insights on **Data Science** and **Artificial intelligence (AI)**

# %% [markdown]
# ---
# # **Table of Contents**
# ---
#
# **1.** [**Introduction**](#Section1)<br>
# **2.** [**Problem Statement**](#Section2)<br>
# **3.** [**Installing & Importing Libraries**](#Section3)<br>
#   - 3.1 [**Installing Libraries**](#Section31)<br>
#   - 3.2 [**Upgrading Libraries**](#Section32)<br>
#   - 3.3 [**Importing Libraries**](#Section33)<br>
#
# **4.** [**Data Acquisition & Description**](#Section4)<br>
# **5.** [**Data Pre-Profiling**](#Section5)<br>
# **6.** [**Data Pre-Processing**](#Section6)<br>
# **7.** [**Data Post-Profiling**](#Section7)<br>
# **8.** [**Exploratory Data Analysis**](#Section8)<br>
#   - [**8.1 What is the variation of CO concentration over time?**](#Section81)<br>
#   - [**8.2 At what hour of the day is Benzene concentration the highest on average?**](#Section82)<br>
#   - [**8.3 What is the monthly trend of NOx concentration?**](#Section83)<br>
#   - [**8.4 What is the distribution of ambient temperature?**](#Section84)<br>
#   - [**8.5 Is there a correlation between NOx and NO2 concentrations?**](#Section85)<br>
#   - [**8.6 How does relative humidity (RH) vary by day of the week?**](#Section86)<br>
#   - [**8.7 Which pollutants have the highest average concentration?**](#Section87)<br>
#   - [**8.8 What is the relationship between temperature and absolute humidity?**](#Section88)<br>
#   - [**8.9 How do NMHC levels trend on a daily basis?**](#Section89)<br>
#   - [**8.10 How does ozone sensor output vary with humidity and temperature?**](#Section810)<br>
#   - [**8.11 How do CO levels differ between daytime and nighttime?**](#Section811)<br>
#   - [**8.12 What is the correlation between all numeric features?**](#Section812)<br>
#
# **9.** [**Summarization**](#Section9)</br>
#   - 9.1 [**Conclusion**](#Section91)</br>
#   - 9.2 [**Actionable Insights**](#Section91)</br>

# %% [markdown]
# ---
# <a name = Section1></a>
# # **1. Introduction**
# ---
#
# Air quality has become a critical focus in urban sustainability due to rising pollution levels from industrialization, vehicular emissions, and population growth. Effective monitoring is essential for assessing pollution exposure, understanding seasonal variations, and enabling data-driven policymaking. This dataset offers a rich source of information for analyzing air pollution through real-time sensor measurements and validated reference analyzer data.
#
# Collected over a one-year period from **March 2004 to February 2005**, the dataset comprises **9358 hourly records** from an **Air Quality Chemical Multisensor Device** deployed at **road level in a polluted Italian city**. It includes sensor responses from **five metal oxide sensors** as well as co-located analyzer readings for critical pollutants like **CO, NOx, NO2, NMHC**, and **Benzene (C6H6)**.
#
# Additionally, the dataset records meteorological conditions such as **temperature**, **relative humidity**, and **absolute humidity**, making it highly suitable for multivariate environmental analysis. Evidence of **sensor drift** and **cross-sensitivity** makes this dataset ideal for exploring **sensor calibration**, **forecasting models**, and **drift compensation** techniques.
#
# Designed strictly for **academic and research use**, this dataset presents valuable opportunities for **EDA**, **predictive modeling**, and **air quality research**, while requiring thoughtful preprocessing due to **missing values coded as -200**.

# %% [markdown]
# ---
# <a name = Section2></a>
# # **2. Problem Statement**
# ---
#
# ## **Problem Statement**
#
# Urban **air pollution** is a major environmental concern, with severe implications for **public health**, **climate change**, and **urban planning**. This dataset provides a rich foundation for analyzing air quality in a **high-traffic Italian city** through a year-long collection of **hourly data**.
#
# <p align="center"><img width = 50% src="https://currentaffairs.adda247.com/wp-content/uploads/multisite/sites/5/2023/11/06110959/aqi_mini-1200x675-1.png"></p>
#
# ### 🔍 EDA Objectives:
#
# - Analyze **pollution trends** and **temporal patterns**
# - Examine **seasonal variations** and **daily cycles**
# - Detect **missing values**, **outliers**, and **sensor drift**
# - Explore **correlations** between pollutants and weather conditions
# - Understand **sensor reliability** and **calibration needs**
#
# This **Exploratory Data Analysis (EDA)** will generate **insights** that inform future **pollution forecasting**, **policy design**, and **machine learning model development**.

# %% [markdown]
# ---
# <a id = Section3></a>
# # **3. Installing & Importing Libraries**
# ---
#
# - This section is emphasised on installing and importing the necessary libraries that will be required.

# %% [markdown]
# <a name = Section31></a>
# ### **3.1 Installing Libraries**

# %%
# !pip install -q datascience                                         # Package that is required by pandas profiling
# !pip install -q pandas-profiling                                    # Library to generate basic statistics about data
# !pip install ydata_profiling
# Out:
# ERROR: Invalid requirement: '#'
# ERROR: Invalid requirement: '#'
# ...
#   Obtaining dependency information for numba<=0.61,>=0.56.0 from https://files.pythonhosted.org/packages/df/a7/56f547de8fc197963f238fd62beb5f1d2cace047602d0577956bf6840970/numba-0.61.0-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
# ...

# %% [markdown]
# <a name = Section32></a>
# ### **3.2 Upgrading Libraries**
#
# - **After upgrading** the libraries, you need to **restart the runtime** to make the libraries in sync.
#
# - Make sure not to execute the cell under Installing Libraries and Upgrading Libraries again after restarting the runtime.

# %%
# !pip install -q --upgrade datascience                               # Package that is required by pandas profiling
# !pip install -q --upgrade pandas-profiling                          # Library to generate basic statistics about data
# !pip install ydata-profiling
# Out:
# ERROR: Invalid requirement: '#'
# ERROR: Invalid requirement: '#'
# ...
# WARNING: visions 0.8.1 does not provide the extra 'type_image_path'

# %% [markdown]
# <a name = Section33></a>
# ### **3.3 Importing Libraries**
#
# - You can headstart with the basic libraries as imported inside the cell below.
#
# - If you want to import some additional libraries, feel free to do so.

# %%
# -------------------------------------------------------------------------------------------------------------------------------
import pandas as pd  # Importing for panel data analysis
from ydata_profiling import ProfileReport  # To perform data profiling

# Pandas display settings to reveal all rows, columns, and values
pd.set_option('display.max_columns', None)      # Show all columns
pd.set_option('display.max_colwidth', None)     # Show full column content
pd.set_option('display.max_rows', None)         # Show all rows
pd.set_option('mode.chained_assignment', None)  # Disable chained assignment warnings
# -------------------------------------------------------------------------------------------------------------------------------
import numpy as np  # For numerical operations
# -------------------------------------------------------------------------------------------------------------------------------
import plotly.graph_objs as go  # For interactive visualizations
# -------------------------------------------------------------------------------------------------------------------------------
import warnings  # Suppress runtime warnings
warnings.filterwarnings("ignore")
# -------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt  # Pyplot for static plotting
import seaborn as sns  # Seaborn for statistical data visualization

# Enable inline plotting in Jupyter Notebook
# %matplotlib inline
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %% [markdown]
# ---
# <a name = Section4></a>
# # **4. Data Acquisition & Description**
# ---
# - This section focuses on acquiring the dataset and understanding its key features.
#
# - The data is sourced from an Air Quality Chemical Multisensor Device deployed in an Italian city. It contains 9358 hourly measurements from March 2004 to February 2005.
#
# - The dataset combines **sensor readings**, **atmospheric conditions**, and **ground truth pollutant levels** from certified analyzers.
#
# - Below is the detailed description of each feature in the dataset:
#
# | Id | Feature             | Description |
# |:--:|:--------------------|:------------|
# | 01 | Date                | Calendar date of the observation |
# | 02 | Time                | Hour of the day (24-hour format) |
# | 03 | CO(GT)              | True hourly averaged concentration of Carbon Monoxide in mg/m³ (reference analyzer) |
# | 04 | PT08.S1(CO)         | Sensor 1 output (targeted at CO) |
# | 05 | NMHC(GT)            | True hourly averaged Non-Methane Hydrocarbons in µg/m³ |
# | 06 | C6H6(GT)            | True hourly averaged Benzene concentration in µg/m³ |
# | 07 | PT08.S2(NMHC)       | Sensor 2 output (targeted at NMHC) |
# | 08 | NOx(GT)             | True hourly averaged Nitrogen Oxides in ppb |
# | 09 | PT08.S3(NOx)        | Sensor 3 output (targeted at NOx) |
# | 10 | NO2(GT)             | True hourly averaged Nitrogen Dioxide in µg/m³ |
# | 11 | PT08.S4(NO2)        | Sensor 4 output (targeted at NO2) |
# | 12 | PT08.S5(O3)         | Sensor 5 output (targeted at Ozone) |
# | 13 | T                  | Ambient Temperature in °C |
# | 14 | RH                 | Relative Humidity in % |
# | 15 | AH                 | Absolute Humidity (derived measure) |
#
# - **Note**: Missing values are represented by `-200`. The dataset captures evidence of sensor drift, cross-sensitivity, and long-term field deployment behavior.

# %%
data = pd.read_csv(filepath_or_buffer = 'https://raw.githubusercontent.com/amitkharche/exploratory_data_analysis_projects_amit_kharche/refs/heads/main/EDA_Air_Quality_Data_amit_kharche/air_quality_uci.csv')
print('Data Shape:', data.shape)
data.head()
# Out:
# Data Shape: (9357, 15)
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  3/10/2004  18:00:00     2.6         1360       150      11.9
# 1  3/10/2004  19:00:00     2.0         1292       112       9.4
# 2  3/10/2004  20:00:00     2.2         1402        88       9.0
# 3  3/10/2004  21:00:00     2.2         1376        80       9.2
# 4  3/10/2004  22:00:00     1.6         1272        51       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692         1268
# 1            955      103          1174       92          1559          972
# 2            939      131          1140      114          1555         1074
# 3            948      172          1092      122          1584         1203
# 4            836      131          1205      116          1490         1110
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# ...

# %% [markdown]
# ### **Data Description**
#
# - To get some quick description out of the data you can use describe method defined in pandas library.

# %%
data.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# ...

# %% [markdown]
# ### **Data Information**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   int64
#  4   NMHC(GT)       9357 non-null   int64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   int64
#  7   NOx(GT)        9357 non-null   int64
#  8   PT08.S3(NOx)   9357 non-null   int64
#  9   NO2(GT)        9357 non-null   int64
#  10  PT08.S4(NO2)   9357 non-null   int64
#  11  PT08.S5(O3)    9357 non-null   int64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# ---
# <a name = Section5></a>
# # **5. Data Pre-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data.
#
# - You need to perform pandas profiling and get some observations out of it...

# %%
from pandas_profiling import ProfileReport

# Generate the profile report
profile = ProfileReport(data, title="Profile Report", explorative=True)

# Save the report as HTML
profile.to_file("Pre_Profiling_Report.html")

print("Profiling report saved successfully!")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Profiling report saved successfully!

# %% [markdown]
# ---
# <a name = Section6></a>
# # **6. Data Pre-Processing**
# ---
#
# - This section is emphasised on performing data manipulation over unstructured data for further processing and analysis.
#
# - To modify unstructured data to strucuted data you need to verify and manipulate the integrity of the data by:
#   - Handling missing data,
#
#   - Handling redundant data,
#
#   - Handling inconsistent data,
#
#   - Handling outliers,
#
#   - Handling typos

# %%
data.isnull().sum().sort_values(ascending= False)
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
### Checking the percentage of NaN values present in each feature

# Making a list of features containing NaN values
features_with_na = [feature for feature in data.columns if data[feature].isnull().sum() > 0]

# Print the feature name and the percentage of missing values
for feature in features_with_na:
    percent_missing = np.round(data[feature].isnull().mean() * 100, 2)
    print(f"{feature}: {percent_missing}% missing values")

# %%
# Strip whitespace from column names
data.columns = data.columns.str.strip()

# Combine 'Date' and 'Time' columns into a single 'Datetime' column
# Use format='mixed' and dayfirst=True to handle inconsistent formats robustly
data['Datetime'] = pd.to_datetime(data['Date'] + ' ' + data['Time'], format='mixed', dayfirst=True, errors='coerce')

# Drop the original 'Date' and 'Time' columns
data.drop(columns=['Date', 'Time'], inplace=True)

# Display the first 5 rows of the updated DataFrame
data.head()
# Out:
#    CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0     2.6         1360       150      11.9           1046      166
# 1     2.0         1292       112       9.4            955      103
# 2     2.2         1402        88       9.0            939      131
# 3     2.2         1376        80       9.2            948      172
# 4     1.6         1272        51       6.5            836      131
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH  \
# 0          1056      113          1692         1268  13.6  48.9  0.7578
# 1          1174       92          1559          972  13.3  47.7  0.7255
# 2          1140      114          1555         1074  11.9  54.0  0.7502
# 3          1092      122          1584         1203  11.0  60.0  0.7867
# 4          1205      116          1490         1110  11.2  59.6  0.7888
#
#              Datetime
# 0 2004-10-03 18:00:00
# 1 2004-10-03 19:00:00
# 2 2004-10-03 20:00:00
# 3 2004-10-03 21:00:00
# ...

# %%
# Drop rows where CO(GT), Temperature (T), or Absolute Humidity (AH) is -200 (i.e., invalid/missing measurements)
data = data[(data['CO(GT)'] != -200) & (data['T'] != -200) & (data['AH'] != -200)]

# Reset index after filtering
data.reset_index(drop=True, inplace=True)

# Check if any -200 values remain in the filtered columns
print("Remaining -200 in CO(GT):", (data['CO(GT)'] == -200).sum())
print("Remaining -200 in T:", (data['T'] == -200).sum())
print("Remaining -200 in AH:", (data['AH'] == -200).sum())

# Preview the cleaned dataset
data.head()
# Out:
# Remaining -200 in CO(GT): 0
# Remaining -200 in T: 0
# Remaining -200 in AH: 0
#    CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0     2.6         1360       150      11.9           1046      166
# 1     2.0         1292       112       9.4            955      103
# 2     2.2         1402        88       9.0            939      131
# 3     2.2         1376        80       9.2            948      172
# 4     1.6         1272        51       6.5            836      131
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH  \
# 0          1056      113          1692         1268  13.6  48.9  0.7578
# 1          1174       92          1559          972  13.3  47.7  0.7255
# 2          1140      114          1555         1074  11.9  54.0  0.7502
# 3          1092      122          1584         1203  11.0  60.0  0.7867
# 4          1205      116          1490         1110  11.2  59.6  0.7888
#
# ...

# %% [markdown]
# ---
# <a name = Section7></a>
# # **7. Data Post-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data after the data manipulation.
#
# - You may end up observing some new changes, so keep it under check and make right observations.

# %%
from pandas_profiling import ProfileReport

# Generate the profile report
profile = ProfileReport(data, title="Profile Report", explorative=True)

# Save the report as HTML
profile.to_file("Post_Profiling_Report.html")

print("Profiling report saved successfully!")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Profiling report saved successfully!

# %% [markdown]
# ---
# <a name = Section8></a>
# # **8. Exploratory Data Analysis**
# ---
#
# - This section is emphasised on asking the right questions and perform analysis using the data.
#
# - Note that there is no limit how deep you can go, but make sure not to get distracted from right track.

# %% [markdown]
# <a name = Section81></a>
# **8.1. How does CO concentration vary over time?**

# %%
plt.figure(figsize=(12, 4))
sns.lineplot(data=data, x='Datetime', y='CO(GT)')
plt.title('CO(GT) Concentration Over Time')
plt.xlabel('Datetime')
plt.ylabel('CO (mg/m³)')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation: CO(GT) Concentration Over Time**
#
# - The CO levels fluctuate significantly across the timeline, with **distinct peaks observed between late 2004 and early 2005**, possibly indicating periods of increased urban activity or colder seasons.
# - From mid-2005 onward, the data becomes **more sparse and segmented**, suggesting potential **sensor downtime, data logging gaps**, or maintenance periods.
# - Overall, CO(GT) concentrations mostly stay within the range of **0–10 mg/m³**, with **occasional spikes** indicating short-term pollution events or traffic surges.

# %% [markdown]
# <a name = Section82></a>
# **8.2. At what hour of the day is Benzene concentration the highest on average?**

# %%
data['Hour'] = data['Datetime'].dt.hour
avg_benzene = data.groupby('Hour')['C6H6(GT)'].mean().reset_index()
sns.barplot(x='Hour', y='C6H6(GT)', data=avg_benzene)
plt.title('Average Benzene Concentration by Hour')
plt.xlabel('Hour of Day')
plt.ylabel('C6H6 (µg/m³)')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation: Average Benzene (C6H6) Concentration by Hour**
#
# - **Benzene levels show two prominent peaks**, one in the **morning around 8–9 AM** and another in the **evening around 6–8 PM**, aligning with **typical traffic rush hours**.
# - Concentrations are lowest during the **early morning hours (3–6 AM)**, likely due to minimal vehicular and industrial activity.
# - The consistent rise during daylight hours followed by a sharp evening spike suggests **human activity and fuel combustion** as major contributors to ambient

# %% [markdown]
# <a name = Section83></a>
# **8.3. What is the monthly trend of NOx concentration?**

# %%
data['Month'] = data['Datetime'].dt.to_period('M')
monthly_nox = data.groupby('Month')['NOx(GT)'].mean().reset_index()
monthly_nox['Month'] = monthly_nox['Month'].astype(str)
plt.figure(figsize=(12, 4))
sns.lineplot(data=monthly_nox, x='Month', y='NOx(GT)')
plt.xticks(rotation=45)
plt.title('Monthly NOx Concentration Trend')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation: Monthly NOx (GT) Concentration Trend**
#
# - The monthly trend shows a **gradual and consistent increase in NOx concentrations** from mid-2004 to the end of 2005, peaking in **December 2005**.
# - The lowest values were recorded between **April and August 2004**, suggesting either cleaner atmospheric conditions or less emission activity during that time.
# - Sharp rises post-August 2004 and again post-June 2005 may indicate **seasonal variations**, increased traffic, or **heating-related emissions** in colder months.

# %% [markdown]
# <a name = Section84></a>
# **8.4. What is the distribution of ambient temperature?**

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(y=data['T'])
plt.title('Temperature Distribution')
plt.ylabel('Temperature (°C)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Observation: Temperature Distribution**
#
# - The temperature values are mostly concentrated between **10°C and 30°C**, indicating a typical temperate climate profile for the recorded region.
# - The distribution is **symmetrical and smooth**, suggesting a balanced range of temperature observations across the dataset.
# - Unlike earlier plots, there are **no extreme outliers like -200°C**, confirming that invalid values have been successfully removed during preprocessing.

# %% [markdown]
# <a name = Section85></a>
# **8.5. Is there a correlation between NOx and NO2 concentrations?**

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(x='NOx(GT)', y='NO2(GT)', data=data)
plt.title('Scatter Plot: NOx vs NO2')
plt.xlabel('NOx (ppb)')
plt.ylabel('NO2 (µg/m³)')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation: Scatter Plot – NOx vs NO2**
#
# - The scatter plot shows a **strong positive correlation** between **NOx (ppb)** and **NO2 (µg/m³)**, indicating that NO2 levels rise with increasing NOx emissions.
# - The dense clustering between **0–600 ppb NOx** and **0–200 µg/m³ NO2** reflects typical urban pollution patterns.
# - However, the presence of outlier values at **-200 on both axes** indicates **invalid or missing data** that should be handled through preprocessing for accurate analysis.

# %% [markdown]
# <a name = Section86></a>
# **8.6. How does relative humidity (RH) vary by day of the week?**

# %%
data['Weekday'] = data['Datetime'].dt.day_name()
avg_rh = data.groupby('Weekday')['RH'].mean().reset_index()
sns.barplot(x='RH', y='Weekday', data=avg_rh.sort_values('RH'))
plt.title('Average Relative Humidity by Weekday')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation: Average Relative Humidity by Weekday**
#
# - Relative humidity levels are **consistently high across all weekdays**, ranging between **approximately 48% and 51%**, showing minimal variation.
# - **Thursday** records the **highest average RH**, while **Tuesday** shows the lowest, though the difference is marginal.
# - The chart suggests that **weekday alone is not a strong influencing factor** for relative humidity, implying external environmental conditions play a more dominant role.

# %% [markdown]
# <a name = Section87></a>
# **8.7. Which pollutants have the highest average concentration?**

# %%
import plotly.express as px

# Select pollutant columns with consistent units or normalize if needed
pollutants = ['CO(GT)', 'C6H6(GT)', 'NOx(GT)', 'NO2(GT)']  # Removed NMHC(GT) if not present

# Compute average values
avg_values = data[pollutants].mean()

# Create donut chart
fig = px.pie(values=avg_values, names=avg_values.index, hole=0.4, title='Average Concentration of Pollutants')
fig.update_traces(textinfo='percent+label')  # Add labels to make small values visible
fig.show()
# Out:
# <div>                            <div id="77e06139-5e81-442b-94c0-b14140d61cfb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77e06139-5e81-442b-94c0-b14140d61cfb")) {                    Plotly.newPlot(                        "77e06139-5e81-442b-94c0-b14140d61cfb",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["CO(GT)","C6H6(GT)","NOx(GT)","NO2(GT)"],"legendgroup":"","name":"","showlegend":true,"values":[2.1297113289760348,10.275735294117647,226.08156318082789,96.65032679738562],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"
# ...

# %% [markdown]
# **Observation: Average Concentration of Pollutants**
#
# - **NOx(GT)** continues to dominate the pollutant profile, contributing approximately **67.5%** of the total average concentration.
# - **NO2(GT)** is the second most significant pollutant, accounting for **28.8%**, both being nitrogen-based and commonly linked to vehicle emissions and industrial processes.
# - **C6H6(GT)** (Benzene) appears more pronounced than before, contributing

# %% [markdown]
# <a name = Section88></a>
# **8.8. What is the relationship between temperature and absolute humidity?**

# %%
# Remove rows with -200 in Temperature or AH
data_filtered = data[(data['T'] != -200) & (data['AH'] != -200)]

# Now plot again
sns.jointplot(data=data_filtered, x='T', y='AH', kind='scatter', height=6)
plt.suptitle('Relationship between Temperature and Absolute Humidity', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation: Relationship between Temperature and Absolute Humidity**
#
# - The scatter plot reveals a **strong positive correlation** between **temperature (T)** and **absolute humidity (AH)** — as temperature increases, AH tends to rise as well.
# - The data points form a clear upward triangular pattern, suggesting that **warmer conditions allow the air to hold more moisture**, which is consistent with physical atmospheric behavior.
# - Both distributions on the axes show that **temperature values are mostly concentrated between 10°C and 30°C**, while **absolute humidity generally ranges from 0.5 to 2.0**, supporting a well-behaved dataset without extreme anomalies.

# %% [markdown]
# <a name = Section89></a>
# **8.9. How do NMHC levels trend on a daily basis?**

# %%
data['DateOnly'] = data['Datetime'].dt.date
daily_nmhc = data.groupby('DateOnly')['NMHC(GT)'].mean().reset_index()
plt.figure(figsize=(12, 4))
sns.lineplot(x='DateOnly', y='NMHC(GT)', data=daily_nmhc)
plt.xticks(rotation=45)
plt.title('Daily NMHC Concentration')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation: Daily NMHC (GT) Concentration**
#
# - The chart displays significant fluctuations in **Non-Methane Hydrocarbon (NMHC)** concentrations during early 2004, with values peaking above **500 µg/m³**.
# - From mid-2004 onward, the trend shows a **sharp drop**, with most values consistently at **-200**, indicating **missing or invalid entries** in the dataset.
# - The dominance of -200 values severely affects the visibility of true trends, highlighting the **need for preprocessing** (e.g., filtering or imputing) before meaningful analysis can be performed on NMHC data.

# %% [markdown]
# <a name = Section810></a>
# **8.10. How does ozone sensor output vary with humidity and temperature?**

# %%
sns.scatterplot(data=data, x='RH', y='PT08.S5(O3)', hue='T', palette='coolwarm')
plt.title('PT08.S5(O3) Sensor vs Relative Humidity')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation: PT08.S5(O3) Sensor vs Relative Humidity**
#
# - The scatter plot shows a **widespread distribution** of ozone sensor responses across varying levels of **relative humidity (RH)**, ranging from 10% to 90%.
# - A **temperature gradient** (color scale) reveals that **lower temperature readings** (blue dots) are associated with **higher sensor outputs**, particularly at **mid to high RH levels**.
# - In contrast, **higher temperatures** (red dots) tend to cluster toward the **left (lower RH)** and show **lower to moderate sensor readings**, suggesting potential temperature sensitivity of the sensor.
# - Overall, the chart indicates that both **RH and temperature jointly influence** the PT08.S5(O3) sensor response, which should be considered in any calibration or prediction modeling.

# %% [markdown]
# <a name = Section811></a>
# **8.11. How do CO levels differ between daytime and nighttime?**

# %%
data['Is_Day'] = data['Hour'].apply(lambda x: 'Day' if 6 <= x <= 18 else 'Night')
sns.boxplot(x='Is_Day', y='CO(GT)', data=data)
plt.title('CO Levels: Day vs Night')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation: CO(GT) Levels – Day vs Night**
#
# - The boxplot shows that **CO concentrations are slightly higher during the daytime** compared to nighttime, with a **higher median** and upper quartile.
# - Both distributions show a wide range with multiple **outliers** above 6 mg/m³, suggesting short-term spikes in carbon monoxide levels likely due to traffic or industrial activity.
# - The spread during night hours is slightly narrower, with a **lower interquartile range**, indicating **more stable or less variable CO levels** at night.
# - These differences suggest that **human activities such as commuting and daytime operations** significantly influence CO emissions.

# %% [markdown]
# <a name = Section812></a>
# **8.12. What is the correlation between all numeric features?**

# %%
# Drop non-numeric columns before computing correlation
numeric_data = data.select_dtypes(include=['number'])

plt.figure(figsize=(12, 8))
sns.heatmap(numeric_data.corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title('Correlation Matrix of All Numeric Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation: Correlation Matrix of All Numeric Features**
#
# - **Strong positive correlations** are observed among:
#   - `CO(GT)` and `PT08.S1(CO)` (**0.88**)
#   - `C6H6(GT)` and `PT08.S2(NMHC)` (**0.98**)
#   - `CO(GT)` and `C6H6(GT)` (**0.93**)
#   - These indicate reliable sensor alignment with their targeted gases.
#
# - **Strong negative correlations** are found between:
#   - `PT08.S3(NOx)` and `NOx(GT)` (**-0.64**)
#   - `CO(GT)` and `PT08.S3(NOx)` (**-0.70**)
#   - `T` and `RH` (**-0.57**), showing expected atmospheric behavior where higher temperatures usually reduce relative humidity.
#
# - The `Hour` feature shows **low to moderate positive correlation** with pollutants like `CO(GT)` and `C6H6(GT)`, hinting at daily patterns in emissions likely tied to human activities.
#
# - **Environmental features (T, RH, AH)** are weakly correlated with most pollutants but should not be ignored, as they may influence sensor behavior or pollutant dispersion.
#
# This matrix highlights the importance of **sensor validation, temporal patterns**, and **environmental interactions** in air quality modeling.

# %% [markdown]
# ---
# <a name = Section9></a>
# # **9. Summarization**
# ---

# %% [markdown]
# <a name = Section91></a>
# ### **9.1 Conclusion**
# - **NOx(GT)** and **NO2(GT)** dominate the pollutant profile, showing strong mutual correlation and significant presence in the atmosphere.
# - **CO(GT)** and **C6H6(GT)** (Benzene) peak during **morning and evening hours**, indicating a strong influence from vehicular traffic.
# - A **strong positive correlation** exists between **temperature (T)** and **absolute humidity (AH)**, aligning with expected climatic behavior.
# - **PT08.S5(O3)** sensor readings are influenced by both **relative humidity and temperature**, requiring calibration adjustments.
# - Multiple columns show invalid readings marked as **-200**, especially in **NMHC(GT)**, affecting trend accuracy.
# - **Daytime CO levels** are slightly higher than nighttime, confirming higher emissions during active hours.
# - **Relative Humidity (RH)** is generally stable across weekdays, with only minor variations.

# %% [markdown]
# <a name = Section92></a>
# ### **9.2 Actionable Insights**
#
# - **Prioritize NOx and NO2 reduction strategies** through traffic regulation, cleaner fuels, and emission control policies.
# - **Implement congestion management** during peak hours to reduce spikes in CO and Benzene concentrations.
# - **Calibrate sensors** regularly for temperature and humidity variations to improve real-time data reliability.
# - **Clean or impute missing values (-200)** in the dataset to enhance model accuracy and analysis quality.
# - **Improve data collection continuity** by maintaining and monitoring sensor uptime.
# - **Use seasonal temperature and humidity patterns** to forecast pollution trends and plan proactive environmental measures.
